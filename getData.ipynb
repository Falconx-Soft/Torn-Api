# %%
import csv
import pandas as pd

# %%
df = pd.DataFrame(pd.read_excel("data.xlsx"))
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
chk = pd.read_excel("data.xlsx")
data = chk.values.tolist()
for d in data:
	temp = d[0].split(" ")
	if len(temp) != 1:
		db_user_id = temp[1].strip("[]")
	else:
		db_user_id = temp[0].strip("[]")
	db_faction = d[2]
	db_totalStats = d[8]
	db_str = d[4]
	db_def = d[5]
	db_spd = d[6]
	db_dex = d[5]
	print(db_user_id,db_faction,db_totalStats,db_str,db_def,db_spd,db_dex)
# Out:
# 99177 Guerrilla Warfare 366811313350471 12157493081145 351683906303850 1454446057797 351683906303850
# 979003 nan 25156673053146 901432451040 24034078486911 218866745971 24034078486911
# 1953860 Relentless 7401822368385 3025103789 495069447 83361774456 495069447
# 247674 JFK 2450178857699 323644672450 2014877117348 61117651001 2014877117348
# 1825532 Chain Reaction 2074423497398 1001199986964 1010961370706 57722518414 1010961370706
# 1785428 Central Federal Reserve 413779808042 68802958729 792517109 1793955773 792517109
# 1517799 nan 357675613214 40008894912 252321930880 60163412065 252321930880
# 2050558 Subversive Alliance 328506660462 232798631940 63313925072 31557550420 63313925072
# 302973 Subversive Alliance 326633719406 39196645816 11761168726 22877619105 11761168726
# 1523811 None 308268590503 103415392068 200700761542 2856992730 200700761542
# 10 nan 242100000000 40000000000 2000000000 200000000000 2000000000
# ...

# %%
for x in range(9):
	print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
